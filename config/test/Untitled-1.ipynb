# %%
# !git clone --recurse-submodules https://github.com/enhuiz/vall-e.git

# %%
# %cd vall-e
# Out:
# /mnt/ext/pjadhav/Research/VoiceClone/Research/Voice_Clone/vall-e
# /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install .
# Out:
# Processing /mnt/ext/pjadhav/Research/VoiceClone/Research/Voice_Clone/vall-e
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: coloredlogs>=15.0.1 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (15.0.1)
# Requirement already satisfied: deepspeed>=0.7.7 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (0.14.4)
# Requirement already satisfied: diskcache>=5.4.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (5.6.3)
# Requirement already satisfied: einops>=0.6.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (0.8.0)
# Requirement already satisfied: encodec>=0.1.1 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (0.1.1)
# Requirement already satisfied: g2p_en>=2.1.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (2.1.0)
# Requirement already satisfied: humanize>=4.4.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (4.9.0)
# Requirement already satisfied: matplotlib>=3.6.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (3.9.0)
# Requirement already satisfied: numpy>=1.23.3 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (1.26.4)
# Requirement already satisfied: omegaconf>=2.2.3 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (2.3.0)
# Requirement already satisfied: openTSNE>=0.6.2 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (1.0.1)
# Requirement already satisfied: pandas>=1.5.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (2.2.2)
# Requirement already satisfied: soundfile>=0.11.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (0.12.1)
# Requirement already satisfied: torch>=1.13.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (2.3.1)
# Requirement already satisfied: torchaudio>=0.13.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (2.3.1)
# Requirement already satisfied: tqdm>=4.64.1 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from vall-e==0.0.1.dev20230119082310) (4.66.4)
# Requirement already satisfied: humanfriendly>=9.1 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from coloredlogs>=15.0.1->vall-e==0.0.1.dev20230119082310) (10.0)
# Requirement already satisfied: hjson in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from deepspeed>=0.7.7->vall-e==0.0.1.dev20230119082310) (3.1.0)
# Requirement already satisfied: ninja in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from deepspeed>=0.7.7->vall-e==0.0.1.dev20230119082310) (1.11.1.1)
# Requirement already satisfied: nvidia-ml-py in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from deepspeed>=0.7.7->vall-e==0.0.1.dev20230119082310) (12.555.43)
# Requirement already satisfied: packaging>=20.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from deepspeed>=0.7.7->vall-e==0.0.1.dev20230119082310) (23.2)
# Requirement already satisfied: psutil in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from deepspeed>=0.7.7->vall-e==0.0.1.dev20230119082310) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from deepspeed>=0.7.7->vall-e==0.0.1.dev20230119082310) (9.0.0)
# Requirement already satisfied: pydantic in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from deepspeed>=0.7.7->vall-e==0.0.1.dev20230119082310) (2.7.4)
# Requirement already satisfied: nltk>=3.2.4 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from g2p_en>=2.1.0->vall-e==0.0.1.dev20230119082310) (3.8.1)
# Requirement already satisfied: inflect>=0.3.1 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from g2p_en>=2.1.0->vall-e==0.0.1.dev20230119082310) (7.3.0)
# Requirement already satisfied: distance>=0.1.3 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from g2p_en>=2.1.0->vall-e==0.0.1.dev20230119082310) (0.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from matplotlib>=3.6.0->vall-e==0.0.1.dev20230119082310) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from matplotlib>=3.6.0->vall-e==0.0.1.dev20230119082310) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from matplotlib>=3.6.0->vall-e==0.0.1.dev20230119082310) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from matplotlib>=3.6.0->vall-e==0.0.1.dev20230119082310) (1.4.5)
# Requirement already satisfied: pillow>=8 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from matplotlib>=3.6.0->vall-e==0.0.1.dev20230119082310) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from matplotlib>=3.6.0->vall-e==0.0.1.dev20230119082310) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from matplotlib>=3.6.0->vall-e==0.0.1.dev20230119082310) (2.9.0.post0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from omegaconf>=2.2.3->vall-e==0.0.1.dev20230119082310) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from omegaconf>=2.2.3->vall-e==0.0.1.dev20230119082310) (6.0.1)
# Requirement already satisfied: scikit-learn>=0.20 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from openTSNE>=0.6.2->vall-e==0.0.1.dev20230119082310) (1.5.0)
# Requirement already satisfied: scipy in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from openTSNE>=0.6.2->vall-e==0.0.1.dev20230119082310) (1.13.1)
# Requirement already satisfied: pytz>=2020.1 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from pandas>=1.5.0->vall-e==0.0.1.dev20230119082310) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from pandas>=1.5.0->vall-e==0.0.1.dev20230119082310) (2024.1)
# Requirement already satisfied: cffi>=1.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from soundfile>=0.11.0->vall-e==0.0.1.dev20230119082310) (1.16.0)
# Requirement already satisfied: filelock in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from torch>=1.13.0->vall-e==0.0.1.dev20230119082310) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from torch>=1.13.0->vall-e==0.0.1.dev20230119082310) (4.11.0)
# Requirement already satisfied: sympy in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from torch>=1.13.0->vall-e==0.0.1.dev20230119082310) (1.12)
# Requirement already satisfied: networkx in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from torch>=1.13.0->vall-e==0.0.1.dev20230119082310) (3.2.1)
# Requirement already satisfied: jinja2 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from torch>=1.13.0->vall-e==0.0.1.dev20230119082310) (3.1.4)
# Requirement already satisfied: fsspec in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from torch>=1.13.0->vall-e==0.0.1.dev20230119082310) (2024.6.0)
# Requirement already satisfied: pycparser in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.11.0->vall-e==0.0.1.dev20230119082310) (2.22)
# Requirement already satisfied: more-itertools in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from inflect>=0.3.1->g2p_en>=2.1.0->vall-e==0.0.1.dev20230119082310) (10.3.0)
# Requirement already satisfied: typeguard>=4.0.1 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from inflect>=0.3.1->g2p_en>=2.1.0->vall-e==0.0.1.dev20230119082310) (4.3.0)
# Requirement already satisfied: click in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from nltk>=3.2.4->g2p_en>=2.1.0->vall-e==0.0.1.dev20230119082310) (8.1.7)
# Requirement already satisfied: joblib in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from nltk>=3.2.4->g2p_en>=2.1.0->vall-e==0.0.1.dev20230119082310) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from nltk>=3.2.4->g2p_en>=2.1.0->vall-e==0.0.1.dev20230119082310) (2024.5.15)
# Requirement already satisfied: six>=1.5 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->vall-e==0.0.1.dev20230119082310) (1.16.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from scikit-learn>=0.20->openTSNE>=0.6.2->vall-e==0.0.1.dev20230119082310) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->vall-e==0.0.1.dev20230119082310) (2.1.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from pydantic->deepspeed>=0.7.7->vall-e==0.0.1.dev20230119082310) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from pydantic->deepspeed>=0.7.7->vall-e==0.0.1.dev20230119082310) (2.18.4)
# Requirement already satisfied: mpmath>=0.19 in /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages (from sympy->torch>=1.13.0->vall-e==0.0.1.dev20230119082310) (1.3.0)
# Building wheels for collected packages: vall-e
#   Building wheel for vall-e (setup.py) ... done
#   Created wheel for vall-e: filename=vall_e-0.0.1.dev20230119082310-py3-none-any.whl size=31159 sha256=44f8d2620e46d61faa0f3903040a9a85491f393c6efdcd3e3235d985a5c11f32
#   Stored in directory: /home/pjadhav/.cache/pip/wheels/d4/c3/ec/f9b392fe718aa2f1a6bc45f83624be67d8539add20939bb19f
# Successfully built vall-e
# Installing collected packages: vall-e
#   Attempting uninstall: vall-e
#     Found existing installation: vall-e 0.0.1.dev20230119082310
#     Uninstalling vall-e-0.0.1.dev20230119082310:
#       Successfully uninstalled vall-e-0.0.1.dev20230119082310
# Successfully installed vall-e-0.0.1.dev20230119082310

# %%
cd data

# %%
# !python -m vall_e.emb.qnt data/train

# %%
# !python -m vall_e.emb.g2p data/test

# %%
# !python -m vall_e.emb.qnt data/test

# %%
# !python -m vall_e.train yaml=config/test/ar.yml
# Out:
# [2024-06-25 00:48:46,382] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.3
#  [WARNING]  using untested triton version (2.3.1), only 1.0.0 is known to be compatible
# Traceback (most recent call last):
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/train.py", line 12, in <module>
#     from .config import cfg
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/config.py", line 96, in <module>
#     cfg = Config.from_cli()
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/utils/config.py", line 95, in from_cli
#     yaml_cfg = OmegaConf.load(cli_cfg.yaml)
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/omegaconf/omegaconf.py", line 189, in load
#     with io.open(os.path.abspath(file_), "r", encoding="utf-8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/ext/pjadhav/Research/VoiceClone/Research/Voice_Clone/config/test/ar.yml'

# %%
# !python -m vall_e.train yaml=config/test/nar.yml
# Out:
# [2024-06-25 00:47:53,282] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.3
#  [WARNING]  using untested triton version (2.3.1), only 1.0.0 is known to be compatible
# Traceback (most recent call last):
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/train.py", line 12, in <module>
#     from .config import cfg
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/config.py", line 96, in <module>
#     cfg = Config.from_cli()
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/utils/config.py", line 95, in from_cli
#     yaml_cfg = OmegaConf.load(cli_cfg.yaml)
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/omegaconf/omegaconf.py", line 189, in load
#     with io.open(os.path.abspath(file_), "r", encoding="utf-8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/ext/pjadhav/Research/VoiceClone/Research/Voice_Clone/config/test/nar.yml'

# %%
# !mkdir -p zoo
# !python -m vall_e.export zoo/ar.pt yaml=config/test/ar.yml
# !python -m vall_e.export zoo/nar.pt yaml=config/test/nar.yml
# Out:
# [2024-07-02 17:40:13,505] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.3
#  [WARNING]  using untested triton version (2.3.1), only 1.0.0 is known to be compatible
# Traceback (most recent call last):
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/export.py", line 5, in <module>
#     from .data import VALLEDatset, create_train_val_dataloader
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/data.py", line 15, in <module>
#     from .config import cfg
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/config.py", line 96, in <module>
#     cfg = Config.from_cli()
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/utils/config.py", line 95, in from_cli
#     yaml_cfg = OmegaConf.load(cli_cfg.yaml)
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/omegaconf/omegaconf.py", line 189, in load
#     with io.open(os.path.abspath(file_), "r", encoding="utf-8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/ext/pjadhav/Research/VoiceClone/Research/Voice_Clone/vall-e/config/test/config/test/ar.yml'
# [2024-07-02 17:40:15,477] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.3
#  [WARNING]  using untested triton version (2.3.1), only 1.0.0 is known to be compatible
# Traceback (most recent call last):
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/export.py", line 5, in <module>
#     from .data import VALLEDatset, create_train_val_dataloader
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/data.py", line 15, in <module>
#     from .config import cfg
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/config.py", line 96, in <module>
#     cfg = Config.from_cli()
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/vall_e/utils/config.py", line 95, in from_cli
#     yaml_cfg = OmegaConf.load(cli_cfg.yaml)
#   File "/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/omegaconf/omegaconf.py", line 189, in load
#     with io.open(os.path.abspath(file_), "r", encoding="utf-8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/ext/pjadhav/Research/VoiceClone/Research/Voice_Clone/vall-e/config/test/config/test/nar.yml'

# %%
# !python -m vall_e 'I am here to make some noise' data/test/p225_001.wav toy2.wav
# Out:
# [2024-06-24 18:27:24,777] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.3
#  [WARNING]  using untested triton version (2.3.1), only 1.0.0 is known to be compatible
# /home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]/home/pjadhav/.conda/envs/Pratiks/lib/python3.10/site-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#  18%|███████▏                               | 183/1000 [00:00<00:04, 184.89it/s]
# toy2.wav saved.

# %%
from IPython.display import Audio
Audio('toy.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
